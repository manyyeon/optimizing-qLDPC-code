# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
import h5py

filepath = "optimization/results/best_neighbor_search_early_stop_run2.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 15  0 20  0 24  0 30  1 15  1 21  1 25  1 31  2 15  2 16  2 22  2 26
#    2 32  3 16  3 20  3 31  3 33  4 16  4 22  4 25  4 30  5 23  5 27  5 32
#    5 34  6 18  6 20  6 27  6 33  7 17  7 22  7 28  7 31  8 17  8 23  8 29
#    8 30  9 17  9 21  9 28  9 32 10 18 10 23 10 26 10 26 11 18 11 24 11 29
#   11 34 12 19 12 21 12 27 12 34 13 19 13 24 13 28 13 33 14 19 14 25 14 29]]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 62.0m 24.27s with 22162 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0044324 ± 0.0000297 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/random_walk_erasure_channel.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 15  0 24  0 28  0 28  1 15  1 21  1 25  1 31  2 15  2 22  2 26  2 27
#    2 34  3 16  3 20  3 29  3 31  4 16  4 22  4 32  4 33  5 16  5 17  5 23
#    5 27  6 20  6 27  6 28  6 32  7 17  7 22  7 31  7 33  8 17  8 23  8 29
#    8 30  9 18  9 21  9 25  9 30 10 18 10 23 10 26 10 30 11 18 11 19 11 24
#   11 29 12 19 12 21 12 32 12 34 13 20 13 24 13 33 13 34 14 19 14 25 14 26]]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 66.0m 23.36s with 28719 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0057438 ± 0.0000338 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/random_walk_erasure_channel.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 100000
# [[ 0 15  0 24  0 28  0 28  1 15  1 21  1 25  1 31  2 15  2 22  2 26  2 27
#    2 34  3 16  3 20  3 29  3 31  4 16  4 22  4 32  4 33  5 16  5 17  5 23
#    5 27  6 20  6 27  6 28  6 32  7 17  7 22  7 31  7 33  8 17  8 23  8 29
#    8 30  9 18  9 21  9 25  9 30 10 18 10 23 10 26 10 30 11 18 11 19 11 24
#   11 29 12 19 12 21 12 32 12 34 13 20 13 24 13 33 13 34 14 19 14 25 14 26]]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 1.0m 20.87s with 577 failures out of 100000 runs.
# Logical error rate for Best neighbor search: 0.00577 ± 0.0002395 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/exploration.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [ 0 19  0 22  0 29  0 33  1 19  1 24  1 25  1 28  2 18  2 18  2 19  2 31
#   2 32  3 15  3 16  3 22  3 34  4 26  4 26  4 30  4 34  5 16  5 22  5 24
#   5 27  6 20  6 28  6 29  6 29  7 17  7 18  7 31  7 33  8 17  8 17  8 20
#   8 25  9 21  9 26  9 32  9 34 10 15 10 23 10 30 10 33 11 16 11 20 11 21
#  11 28 12 23 12 27 12 30 12 32 13 21 13 24 13 27 13 31 14 15 14 23 14 25]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 68.0m 16.27s with 22583 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0045166 ± 0.0000300 (stderr)

# %%
from optimization.experiments_settings import from_edgelist
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
import numpy as np

filepath = "optimization/results/sim_ann_deltalog.hdf5"
code_name = "[1225,65]"  # Update this key if needed
# MC_budget = int(1e6 * 5)
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    beta4 = grp['beta=10']

    cost_list = beta4['cost']
    state_list = beta4['theta']

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0001 in index 743
# [ 0 29  0 30  0 33  0 36  0 44  1 26  1 34  1 39  1 48  2 35  2 39  2 40
#   2 43  3 24  3 28  3 31  3 42  3 45  4 25  4 36  4 40  4 41  5 24  5 31
#   5 37  5 44  6 33  6 34  6 43  6 48  7 23  7 25  7 34  7 36  8 23  8 38
#   8 41  8 42  9 22  9 27  9 32  9 46 10 21 10 26 10 44 10 45 11 28 11 29
#  11 31 11 45 12 28 12 32 12 32 12 41 13 21 13 25 13 26 13 30 14 21 14 40
#  14 47 14 47 15 22 15 24 15 38 15 43 16 23 16 29 16 39 16 46 17 33 17 37
#  17 38 17 42 18 27 18 37 18 46 18 47 19 22 19 27 19 35 20 30 20 35 20 48]
# H: [28, 7, 10]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 10]]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 273.0m 37.73s with 10834 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0021668 ± 0.0000208 (stderr)

# %%
import h5py
import numpy as np
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
from optimization.logical_guided_search.logical_guided_eval import evaluate_mc, compute_weighted_low_weight_score, get_code_parameters_and_matrices
from optimization.logical_guided_search.logical_guided_search_core import format_score_info


filepath = "optimization/results/sim_ann_deltalog.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    beta4 = grp['beta=10']

    cost_list = beta4['cost']
    state_list = beta4['theta']

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

run_name = f"exploration_{code_name}_p{p}_MC{MC_budget}"

params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
        state=best_state,
        params=params,
        beta=0.3,
        max_weight_offset=4,
    )
print(format_score_info(score_info))

# cost_result = evaluate_mc(
#         Hx,
#         Hz,
#         p,
#         MC_budget,
#         run_label=run_name,
#         failure_cap=None,
#         min_runs_before_stop=0,
#         workers=32,
#         batch_size=10000,
#     )
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0001 in index 743
# [ 0 29  0 30  0 33  0 36  0 44  1 26  1 34  1 39  1 48  2 35  2 39  2 40
#   2 43  3 24  3 28  3 31  3 42  3 45  4 25  4 36  4 40  4 41  5 24  5 31
#   5 37  5 44  6 33  6 34  6 43  6 48  7 23  7 25  7 34  7 36  8 23  8 38
#   8 41  8 42  9 22  9 27  9 32  9 46 10 21 10 26 10 44 10 45 11 28 11 29
#  11 31 11 45 12 28 12 32 12 32 12 41 13 21 13 25 13 26 13 30 14 21 14 40
#  14 47 14 47 15 22 15 24 15 38 15 43 16 23 16 29 16 39 16 46 17 33 17 37
#  17 38 17 42 18 27 18 37 18 46 18 47 19 22 19 27 19 35 20 30 20 35 20 48]
# weight_patterns={10: 4, 11: 14, 12: 16, 13: 20, 14: 20}, score=10.342

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/exploration.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    cost_list = grp['values'][:]
    state_list = grp['states'][:]

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0005 in index 410
# [ 0 30  0 33  0 35  0 40  0 47  1 21  1 43  1 47  1 48  2 21  2 27  2 28
#   2 43  3 22  3 23  3 32  3 37  3 38  4 23  4 27  4 31  4 36  5 22  5 37
#   5 45  5 48  6 25  6 27  6 28  6 42  7 33  7 36  7 36  7 43  8 23  8 34
#   8 37  8 45  9 24  9 26  9 29  9 38 10 24 10 31 10 42 10 46 11 21 11 24
#  11 44 11 44 12 30 12 39 12 39 12 46 13 25 13 31 13 35 13 45 14 25 14 34
#  14 40 14 47 15 22 15 26 15 29 15 40 16 32 16 39 16 44 16 48 17 26 17 34
#  17 41 17 42 18 30 18 32 18 41 18 46 19 28 19 38 19 41 20 29 20 33 20 35]
# H: [28, 7, 10]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 10]]
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 206.0m 38.93s with 10241 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0020482 ± 0.0000202 (stderr)

# %%
import h5py
import numpy as np
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
from optimization.logical_guided_search.logical_guided_eval import evaluate_mc, compute_weighted_low_weight_score, get_code_parameters_and_matrices
from optimization.logical_guided_search.logical_guided_search_core import format_score_info


filepath = "optimization/results/exploration.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    cost_list = grp['values'][:]
    state_list = grp['states'][:]

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

run_name = f"exploration_{code_name}_p{p}_MC{MC_budget}"

params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
        state=best_state,
        params=params,
        beta=0.3,
        max_weight_offset=4,
    )
print(format_score_info(score_info))

cost_result = evaluate_mc(
        Hx,
        Hz,
        p,
        MC_budget,
        run_label=run_name,
        failure_cap=None,
        min_runs_before_stop=0,
        workers=32,
        batch_size=10000,
    )
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0005 in index 410
# [ 0 30  0 33  0 35  0 40  0 47  1 21  1 43  1 47  1 48  2 21  2 27  2 28
#   2 43  3 22  3 23  3 32  3 37  3 38  4 23  4 27  4 31  4 36  5 22  5 37
#   5 45  5 48  6 25  6 27  6 28  6 42  7 33  7 36  7 36  7 43  8 23  8 34
#   8 37  8 45  9 24  9 26  9 29  9 38 10 24 10 31 10 42 10 46 11 21 11 24
#  11 44 11 44 12 30 12 39 12 39 12 46 13 25 13 31 13 35 13 45 14 25 14 34
#  14 40 14 47 15 22 15 26 15 29 15 40 16 32 16 39 16 44 16 48 17 26 17 34
#  17 41 17 42 18 30 18 32 18 41 18 46 19 28 19 38 19 41 20 29 20 33 20 35]
# weight_patterns={10: 8, 11: 14, 12: 11, 13: 19, 14: 23}, score=13.8893
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/
failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch483: 0.0021 ± 0.0004578 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch484 finished in 0.0m 4.18s with 24 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch484: 0.0024 ± 0.0004893 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch485 finished in 0.0m 4.25s with 23 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch485: 0.0023 ± 0.0004791 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch486 finished in 0.0m 4.01s with 18 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch486: 0.0018 ± 0.0004239 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch487 finished in 0.0m 4.24s with 20 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch487: 0.002 ± 0.0004468 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch488 finished in 0.0m 4.47s with 27 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch488: 0.0027 ± 0.0005189 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch489 finished in 0.0m 4.25s with 18 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch489: 0.0018 ± 0.0004239 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch490 finished in 0.0m 4.37s with 24 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch490: 0.0024 ± 0.0004893 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch491 finished in 0.0m 4.11s with 14 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch491: 0.0014 ± 0.0003739 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch492 finished in 0.0m 4.81s with 15 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch492: 0.0015 ± 0.0003870 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch493 finished in 0.0m 4.12s with 18 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch493: 0.0018 ± 0.0004239 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch494 finished in 0.0m 4.08s with 16 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch494: 0.0016 ± 0.0003997 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch495 finished in 0.0m 4.11s with 28 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch495: 0.0028 ± 0.0005284 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch496 finished in 0.0m 3.97s with 17 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch496: 0.0017 ± 0.0004120 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch497 finished in 0.0m 4.30s with 14 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch497: 0.0014 ± 0.0003739 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch498 finished in 0.0m 4.13s with 22 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch498: 0.0022 ± 0.0004685 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch499 finished in 0.0m 4.11s with 18 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch499: 0.0018 ± 0.0004239 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000 finished in 35.0m 42.70s with 10136 failures out of 5000000/5000000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000: 0.0020272 ± 0.0000201 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_old_parents_included_1e5_run1.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # cost_list = grp['values'][:]
    # state_list = grp['states'][:]

    # min_cost = np.min(cost_list)
    # min_idx = np.argmin(cost_list)

    # print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}"

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 21  0 28  0 35  0 42  0 48  1 21  1 29  1 36  1 41  2 21  2 30  2 37
#    2 43  3 22  3 38  3 39  3 43  3 47  4 22  4 31  4 36  4 42  5 32  5 34
#    5 37  5 44  6 23  6 28  6 34  6 44  7 23  7 33  7 36  7 43  8 23  8 38
#    8 39  8 46  9 24  9 29  9 45  9 45 10 24 10 31 10 35 10 46 11 24 11 33
#   11 40 11 44 12 25 12 29 12 37 12 40 13 25 13 32 13 35 13 45 14 25 14 28
#   14 34 14 47 15 26 15 30 15 39 15 46 16 26 16 31 16 38 16 47 17 22 17 26
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 32 19 41 20 27 20 33 20 42]]
# H: [28, 7, 10]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 10]]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 235.0m 58.95s with 10643 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0021286 ± 0.0000206 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_old_parents_included_1e5_run1.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)

    print(f"min cost saved: {min_cost}")

    print(best_state_edge_list)

params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
        state=best_state,
        params=params,
        beta=0.3,
        max_weight_offset=4,
    )
print(format_score_info(score_info))

# cost_result = evaluate_mc(
#         Hx,
#         Hz,
#         p,
#         MC_budget,
#         run_label=run_name,
#         failure_cap=None,
#         min_runs_before_stop=0,
#         workers=32,
#         batch_size=10000,
#     )
# Out:
# MC_budget set to: 5000000
# min cost saved: 0.00178
# [[ 0 21  0 28  0 35  0 42  0 48  1 21  1 29  1 36  1 41  2 21  2 30  2 37
#    2 43  3 22  3 38  3 39  3 43  3 47  4 22  4 31  4 36  4 42  5 32  5 34
#    5 37  5 44  6 23  6 28  6 34  6 44  7 23  7 33  7 36  7 43  8 23  8 38
#    8 39  8 46  9 24  9 29  9 45  9 45 10 24 10 31 10 35 10 46 11 24 11 33
#   11 40 11 44 12 25 12 29 12 37 12 40 13 25 13 32 13 35 13 45 14 25 14 28
#   14 34 14 47 15 26 15 30 15 39 15 46 16 26 16 31 16 38 16 47 17 22 17 26
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 32 19 41 20 27 20 33 20 42]]
# weight_patterns={10: 6, 11: 10, 12: 23, 13: 18, 14: 14}, score=11.6694

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_L15_old_parents_included_1e5_run1.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # cost_list = grp['values'][:]
    # state_list = grp['states'][:]

    # min_cost = np.min(cost_list)
    # min_idx = np.argmin(cost_list)

    # print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}"

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 21  0 21  0 28  0 32  0 42  1 29  1 35  1 36  1 41  2 21  2 30  2 37
#    2 43  3 22  3 28  3 38  3 43  3 43  4 22  4 31  4 36  4 42  5 22  5 32
#    5 32  5 37  6 23  6 28  6 39  6 44  7 23  7 33  7 36  7 47  8 23  8 34
#    8 37  8 45  9 24  9 29  9 38  9 45 10 24 10 31 10 35 10 46 11 24 11 33
#   11 40 11 44 12 25 12 29 12 39 12 46 13 25 13 35 13 45 13 48 14 25 14 34
#   14 40 14 47 15 26 15 30 15 38 15 46 16 26 16 31 16 39 16 47 17 26 17 34
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 41 19 44 20 27 20 33 20 42]]
# H: [28, 7, 9]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 9]]
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 139.0m 20.70s with 10919 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0021838 ± 0.0000209 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_L15_old_parents_included_1e5_run1.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)

    print(f"min cost saved: {min_cost}")

    print(best_state_edge_list)

params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
    state=best_state,
    params=params,
    beta=0.3,
    max_weight_offset=5,
)
print(format_score_info(score_info))

# cost_result = evaluate_mc(
#     Hx,
#     Hz,
#     p,
#     MC_budget,
#     run_label=run_name,
#     failure_cap=None,
#     min_runs_before_stop=0,
#     workers=32,
#     batch_size=10000,
# )
# Out:
# MC_budget set to: 5000000
# min cost saved: 0.0018
# [[ 0 21  0 21  0 28  0 32  0 42  1 29  1 35  1 36  1 41  2 21  2 30  2 37
#    2 43  3 22  3 28  3 38  3 43  3 43  4 22  4 31  4 36  4 42  5 22  5 32
#    5 32  5 37  6 23  6 28  6 39  6 44  7 23  7 33  7 36  7 47  8 23  8 34
#    8 37  8 45  9 24  9 29  9 38  9 45 10 24 10 31 10 35 10 46 11 24 11 33
#   11 40 11 44 12 25 12 29 12 39 12 46 13 25 13 35 13 45 13 48 14 25 14 34
#   14 40 14 47 15 26 15 30 15 38 15 46 16 26 16 31 16 39 16 47 17 26 17 34
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 41 19 44 20 27 20 33 20 42]]
# weight_patterns={9: 4, 10: 1, 11: 7, 12: 18, 13: 25, 14: 26}, score=5.68168

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_old_parents_included_1e5_run1.hdf5"
code_name = "[1600,64]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 24  0 32  0 39  0 49  1 24  1 33  1 40  1 48  1 55  2 24  2 34  2 41
#    2 50  3 25  3 32  3 42  3 50  3 55  4 25  4 35  4 38  4 41  5 25  5 36
#    5 43  5 48  6 26  6 32  6 44  6 51  7 26  7 37  7 40  7 52  8 26  8 37
#    8 41  8 53  9 27  9 33  9 42  9 52 10 27 10 35 10 44 10 53 11 27 11 43
#   11 49 11 51 12 28 12 33 12 45 12 51 13 28 13 36 13 44 13 50 14 30 14 38
#   14 46 14 49 15 29 15 34 15 42 15 46 16 29 16 36 16 39 16 47 17 29 17 37
#   17 45 17 54 18 30 18 34 18 43 18 54 19 28 19 38 19 47 19 55 20 30 20 45
#   20 52 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 53 23 31 23 40 23 47]]
# H: [32, 8, 10]
# H^T: [24, 0, inf]
# Q: [[1600, 64, 10]]
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 228.0m 7.17s with 7374 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0014748 ± 0.0000172 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_old_parents_included_1e5_run1.hdf5"
code_name = "[1600,64]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)
    print(f"min cost saved: {min_cost}")

    print(best_state_edge_list)

params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
        state=best_state,
        params=params,
        beta=0.3,
        max_weight_offset=4,
    )
print(format_score_info(score_info))

# cost_result = evaluate_mc(
#         Hx,
#         Hz,
#         p,
#         MC_budget,
#         run_label=run_name,
#         failure_cap=None,
#         min_runs_before_stop=0,
#         workers=32,
#         batch_size=10000,
#     )
# Out:
# MC_budget set to: 5000000
# min cost saved: 0.00135
# [[ 0 24  0 32  0 39  0 49  1 24  1 33  1 40  1 48  1 55  2 24  2 34  2 41
#    2 50  3 25  3 32  3 42  3 50  3 55  4 25  4 35  4 38  4 41  5 25  5 36
#    5 43  5 48  6 26  6 32  6 44  6 51  7 26  7 37  7 40  7 52  8 26  8 37
#    8 41  8 53  9 27  9 33  9 42  9 52 10 27 10 35 10 44 10 53 11 27 11 43
#   11 49 11 51 12 28 12 33 12 45 12 51 13 28 13 36 13 44 13 50 14 30 14 38
#   14 46 14 49 15 29 15 34 15 42 15 46 16 29 16 36 16 39 16 47 17 29 17 37
#   17 45 17 54 18 30 18 34 18 43 18 54 19 28 19 38 19 47 19 55 20 30 20 45
#   20 52 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 53 23 31 23 40 23 47]]
# weight_patterns={10: 1, 11: 0, 12: 29, 13: 0, 14: 64}, score=4.1284

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/best_neighbor_search_early_stop.hdf5"
code_name = "[1600,64]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 24  0 32  0 47  0 49  1 24  1 33  1 40  1 48  1 55  2 24  2 34  2 41
#    2 44  3 25  3 32  3 42  3 50  3 55  4 25  4 35  4 41  4 51  5 25  5 36
#    5 43  5 53  6 26  6 32  6 44  6 51  7 26  7 28  7 40  7 52  8 26  8 41
#    8 46  8 53  9 27  9 28  9 33  9 42 10 27 10 35 10 50 10 53 11 27 11 43
#   11 45 11 49 12 33 12 37 12 45 12 51 13 28 13 36 13 44 13 50 14 38 14 38
#   14 49 14 52 15 29 15 34 15 42 15 46 16 29 16 36 16 38 16 47 17 29 17 37
#   17 45 17 54 18 30 18 34 18 43 18 54 19 30 19 39 19 47 19 55 20 30 20 37
#   20 39 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 48 23 31 23 40 23 52]]
# H: [32, 8, 10]
# H^T: [24, 0, inf]
# Q: [[1600, 64, 10]]
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 282.0m 28.90s with 7736 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0015472 ± 0.0000176 (stderr)

# %%
from optimization.experiments_settings import from_edgelist
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
import numpy as np

filepath = "optimization/results/sim_ann_deltalog.hdf5"
code_name = "[1600,64]"  # Update this key if needed
# MC_budget = int(1e6 * 5)
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    beta4 = grp['beta=10']

    cost_list = beta4['cost']
    state_list = beta4['theta']

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate simmulated annealing: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate simmulated annealing: 0.0005 in index 209
# [ 0 24  0 26  0 41  0 55  1 34  1 34  1 36  1 36  1 52  2 24  2 35  2 38
#   2 45  3 26  3 32  3 44  3 45  3 48  4 39  4 42  4 49  4 55  5 28  5 43
#   5 47  5 52  6 28  6 37  6 45  6 50  7 24  7 35  7 40  7 49  8 31  8 38
#   8 48  8 52  9 40  9 41  9 42  9 55 10 25 10 32 10 34 10 47 11 33 11 42
#  11 44 11 47 12 35 12 38 12 51 12 53 13 37 13 40 13 53 13 54 14 32 14 41
#  14 46 14 54 15 27 15 39 15 46 15 51 16 27 16 29 16 43 16 49 17 25 17 29
#  17 37 17 46 18 28 18 30 18 43 18 44 19 27 19 36 19 48 19 50 20 29 20 30
#  20 31 21 33 21 50 21 51 21 54 22 26 22 30 22 33 22 53 23 25 23 31 23 39]
# H: [32, 8, 10]
# H^T: [24, 0, inf]
# Q: [[1600, 64, 10]]
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 288.0m 9.97s with 10127 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0020254 ± 0.0000201 (stderr)

# %%
from optimization.experiments_settings import from_edgelist
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
import numpy as np

filepath = "optimization/results/sim_ann_deltalog.hdf5"
code_name = "[2025,81]"  # Update this key if needed
# MC_budget = int(1e6 * 5)
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    beta4 = grp['beta=10']

    cost_list = beta4['cost']
    state_list = beta4['theta']

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate simmulated annealing: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate simmulated annealing: 0.0234 in index 41
# [ 0 36  0 42  0 44  0 55  1 27  1 37  1 56  1 57  2 38  2 45  2 46  2 53
#   3 28  3 39  3 47  3 58  4 37  4 39  4 46  4 61  5 28  5 40  5 48  5 54
#   6 27  6 29  6 49  6 53  7 29  7 41  7 46  7 58  8 29  8 34  8 48  8 59
#   9 37  9 40  9 49  9 52 10 36 10 56 10 59 10 60 11 30 11 41 11 45 11 57
#  12 31 12 54 12 57 12 59 13 34 13 42 13 50 13 60 14 30 14 31 14 32 14 33
#  15 35 15 40 15 43 15 47 16 27 16 30 16 51 16 55 17 32 17 32 17 52 17 55
#  18 38 18 47 18 48 18 56 19 33 19 41 19 51 19 62 20 33 20 43 20 54 21 28
#  21 34 21 39 21 51 22 42 22 43 22 49 22 61 22 61 23 31 23 44 23 50 23 62
#  24 35 24 44 24 52 24 62 25 38 25 50 25 58 25 60 26 35 26 36 26 45 26 53]
# H: [36, 9, 10]
# H^T: [27, 0, inf]
# Q: [[2025, 81, 10]]
# Hx, Hz, Lx, Lz: (972, 2025), (972, 2025), (81, 2025), (81, 2025)
# BP max iterations: 202, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 377.0m 51.93s with 5267 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0010534 ± 0.0000145 (stderr)

# %%
from optimization.experiments_settings import from_edgelist
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
import numpy as np

filepath = "optimization/results/sim_ann_deltalog.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    beta4 = grp['beta=10']

    cost_list = beta4['cost']
    state_list = beta4['theta']

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate simmulated annealing: {min_cost} under erasure channel index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
        state=best_state,
        params=params,
        beta=0.3,
        max_weight_offset=6,
    )
print(format_score_info(score_info))

print(best_state_edge_list)

cost_result = evaluate_mc(
    Hx,
    Hz,
    p,
    MC_budget,
    run_label=run_name,
    failure_cap=None,
    min_runs_before_stop=0,
    workers=32,
    batch_size=10000,
)
# Out:
# MC_budget set to: 5000000
# logical error rate simmulated annealing: 0.0234 under erasure channel index 41
# weight_patterns={10: 1, 11: 3, 12: 6, 13: 15, 14: 27, 15: 48, 16: 62}, score=3.22554
# [ 0 36  0 42  0 44  0 55  1 27  1 37  1 56  1 57  2 38  2 45  2 46  2 53
#   3 28  3 39  3 47  3 58  4 37  4 39  4 46  4 61  5 28  5 40  5 48  5 54
#   6 27  6 29  6 49  6 53  7 29  7 41  7 46  7 58  8 29  8 34  8 48  8 59
#   9 37  9 40  9 49  9 52 10 36 10 56 10 59 10 60 11 30 11 41 11 45 11 57
#  12 31 12 54 12 57 12 59 13 34 13 42 13 50 13 60 14 30 14 31 14 32 14 33
#  15 35 15 40 15 43 15 47 16 27 16 30 16 51 16 55 17 32 17 32 17 52 17 55
#  18 38 18 47 18 48 18 56 19 33 19 41 19 51 19 62 20 33 20 43 20 54 21 28
#  21 34 21 39 21 51 22 42 22 43 22 49 22 61 22 61 23 31 23 44 23 50 23 62
#  24 35 24 44 24 52 24 62 25 38 25 50 25 58 25 60 26 35 26 36 26 45 26 53]
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch0 finished in 0.0m 7.19s with 7 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch0: 0.0007 ± 0.0002645 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch1 finished in 0.0m 7.50s with 11 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch1: 0.0011 ± 0.0003315 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch2 finished in 0.0m 7.43s with 13 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch2: 0.0013 ± 0.0003603 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch3 finished in 0.0m 7.49s with 11 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch3: 0.0011 ± 0.0003315 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch4 finished in 0.0m 7.51s with 17 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch4: 0.0017 ± 0.0004120 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch5 finished in 0.0m 7.18s with 10 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch5: 0.001 ± 0.0003161 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch6 finished in 0.0m 7.54s with 9 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch6: 0.0009 ± 0.0002999 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch7 finished in 0.0m 7.31s with 12 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch7: 0.0012 ± 0.0003462 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch8 finished in 0.0m 9.35s with 8 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch8: 0.0008 ± 0.0002827 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch9 finished in 0.0m 11.27s with 11 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch9: 0.0011 ± 0.0003315 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch10 finished in 0.0m 13.28s with 7 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch10: 0.0007 ± 0.0002645 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch11 finished in 0.0m 11.44s with 9 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch11: 0.0009 ± 0.0002999 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch12 finished in 0.0m 10.93s with 11 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch12: 0.0011 ± 0.0003315 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch13 finished in 0.0m 13.83s with 4 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch13: 0.0004 ± 0.0002000 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch14 finished in 0.0m 10.96s with 18 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch14: 0.0018 ± 0.0004239 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch15 finished in 0.0m 11.15s with 12 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch15: 0.0012 ± 0.0003462 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch16 finished in 0.0m 7.91s with 9 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_bat
(stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch496 finished in 0.0m 10.42s with 9 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch496: 0.0009 ± 0.0002999 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch497 finished in 0.0m 9.50s with 12 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch497: 0.0012 ± 0.0003462 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch498 finished in 0.0m 10.10s with 13 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch498: 0.0013 ± 0.0003603 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000_batch499 finished in 0.0m 9.81s with 9 failures out of 10000/10000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000_batch499: 0.0009 ± 0.0002999 (stderr)
# Decoder exploration_[1225,65]_p0.03_MC5000000 finished in 80.0m 17.41s with 5313 failures out of 5000000/5000000 runs.
# Logical error rate for exploration_[1225,65]_p0.03_MC5000000: 0.0010626 ± 0.0000146 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/best_neighbor_search_early_stop.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 27  0 36  0 44  0 55  1 27  1 37  1 46  1 56  2 38  2 40  2 45  2 53
#    3 36  3 47  3 50  3 56  4 28  4 39  4 46  4 55  5 28  5 40  5 48  5 54
#    6 29  6 36  6 49  6 57  7 29  7 41  7 46  7 58  8 29  8 42  8 48  8 59
#    9 30  9 37  9 49  9 52 10 30 10 40 10 50 10 57 11 30 11 41 11 45 11 59
#   12 31 12 37 12 51 12 59 13 28 13 31 13 42 13 60 14 31 14 43 14 47 14 58
#   15 32 15 38 15 47 15 60 16 27 16 32 16 51 16 55 17 32 17 35 17 42 17 52
#   18 33 18 38 18 48 18 61 19 33 19 41 19 51 19 62 20 33 20 43 20 49 21 34
#   21 39 21 53 21 57 22 34 22 43 22 54 22 56 22 61 23 34 23 44 23 50 23 62
#   24 35 24 39 24 52 24 62 25 35 25 44 25 53 25 58 26 45 26 54 26 60 26 61]]
# H: [36, 9, 12]
# H^T: [27, 0, inf]
# Q: [[2025, 81, 12]]
# Hx, Hz, Lx, Lz: (972, 2025), (972, 2025), (81, 2025), (81, 2025)
# BP max iterations: 202, OSD order: 2, MS scaling factor: 0.625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 19
#      15     best_state = from_edgelist(best_state_edge_list)
#      17     print(best_state_edge_list)
# ---> 19 cost_result = evaluate_performance_of_state(
#      20     state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
#
# File ~/data/git/optimizing-qLDPC-code/optimization/analyze_codes/decoder_performance_from_state.py:151, in evaluate_performance_of_state(state, p_vals, MC_budget, bp_max_iter, run_label, distance_threshold, canskip)
#     137 for p in p_vals:
#     138     # print(f"Evaluating for p={p}...")
#     139     # if the name of parity check matrix and the logical operators are Hz and Lz, respectively, then it's bit-flip (X) error decoder
#     140     bp_osd_decoder = BpOsdDecoder(
#     141         pcm=Hz,
#     142         error_rate=float(p),
#    (...)
#     148         osd_order=osd_order,
#     149     )
# --> 151     logical_error_rate, stderr, runtime = compute_logical_error_rate(Hz, Lz, p, run_count=MC_budget, DECODER=bp_osd_decoder, run_label=run_label, DEBUG=False)
#     153     logical_error_rates.append(logical_error_rate)
#     154     stderrs.append(stderr)
#
# File ~/data/git/optimizing-qLDPC-code/decoder_performance.py:59, in compute_logical_error_rate(H, L, error_rate, run_count, DECODER, run_label, DEBUG)
#      57 error = generate_bsc_error(H.shape[1], error_rate)
#      58 syndrome = (H @ error) % 2
# ---> 59 decoding = DECODER.decode(syndrome)
#      60 residual = (decoding + error) % 2
#      62 if isinstance(DECODER, BpDecoder):
#
# KeyboardInterrupt:

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_old_parents_included_1e5_run1.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 27  0 36  0 44  0 55  1 27  1 37  1 46  1 56  2 27  2 38  2 45  2 53
#    3 36  3 47  3 56  3 56  4 28  4 39  4 46  4 55  5 28  5 40  5 48  5 54
#    6 29  6 36  6 49  6 57  7 29  7 41  7 46  7 58  8 29  8 42  8 48  8 59
#    9 30  9 37  9 49  9 52 10 30 10 40 10 50 10 57 11 30 11 41 11 45 11 59
#   12 31 12 37 12 51 12 59 13 31 13 42 13 50 13 60 14 31 14 43 14 47 14 58
#   15 32 15 38 15 47 15 60 16 32 16 40 16 52 16 55 17 32 17 42 17 44 17 61
#   18 33 18 38 18 48 18 61 19 33 19 41 19 51 19 62 20 33 20 43 20 49 21 34
#   21 39 21 53 21 57 22 28 22 34 22 43 22 44 22 61 23 34 23 50 23 54 23 62
#   24 35 24 39 24 52 24 62 25 35 25 51 25 53 25 58 26 35 26 45 26 54 26 60]]
# H: [36, 9, 12]
# H^T: [27, 0, inf]
# Q: [[2025, 81, 12]]
# Hx, Hz, Lx, Lz: (972, 2025), (972, 2025), (81, 2025), (81, 2025)
# BP max iterations: 202, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 392.0m 49.87s with 4945 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.000989 ± 0.0000141 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_old_parents_included_1e5_run1.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)
    print(f"min cost saved: {min_cost}")

params, Hx, Hz = get_code_parameters_and_matrices(best_state)

score_info = compute_weighted_low_weight_score(
    state=best_state,
    params=params,
    beta=0.3,
    max_weight_offset=4,
)
print(format_score_info(score_info))

# cost_result = evaluate_mc(
#     Hx,
#     Hz,
#     p,
#     MC_budget,
#     run_label=run_name,
#     failure_cap=None,
#     min_runs_before_stop=0,
#     workers=32,
#     batch_size=10000,
# )
# Out:
# MC_budget set to: 5000000
# [[ 0 27  0 36  0 44  0 55  1 27  1 37  1 46  1 56  2 27  2 38  2 45  2 53
#    3 36  3 47  3 56  3 56  4 28  4 39  4 46  4 55  5 28  5 40  5 48  5 54
#    6 29  6 36  6 49  6 57  7 29  7 41  7 46  7 58  8 29  8 42  8 48  8 59
#    9 30  9 37  9 49  9 52 10 30 10 40 10 50 10 57 11 30 11 41 11 45 11 59
#   12 31 12 37 12 51 12 59 13 31 13 42 13 50 13 60 14 31 14 43 14 47 14 58
#   15 32 15 38 15 47 15 60 16 32 16 40 16 52 16 55 17 32 17 42 17 44 17 61
#   18 33 18 38 18 48 18 61 19 33 19 41 19 51 19 62 20 33 20 43 20 49 21 34
#   21 39 21 53 21 57 22 28 22 34 22 43 22 44 22 61 23 34 23 50 23 54 23 62
#   24 35 24 39 24 52 24 62 25 35 25 51 25 53 25 58 26 35 26 45 26 54 26 60]]
# min cost saved: 0.0008
# weight_patterns={12: 14, 13: 16, 14: 40, 15: 32, 16: 52}, score=23.6852

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/exploration.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    cost_list = grp['values'][:]
    state_list = grp['states'][:]

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0277 in index 146
# [ 0 36  0 44  0 45  0 55  1 27  1 46  1 53  1 59  2 37  2 38  2 53  2 57
#   3 28  3 29  3 36  3 47  4 28  4 32  4 39  4 56  5 28  5 48  5 49  5 54
#   6 36  6 45  6 49  6 61  7 29  7 34  7 41  7 46  8 29  8 48  8 51  8 59
#   9 30  9 40  9 52  9 58 10 30 10 38 10 40 10 57 11 27 11 30 11 37 11 41
#  12 31 12 37 12 51 12 59 13 31 13 42 13 50 13 60 14 31 14 43 14 47 14 58
#  15 32 15 34 15 47 15 50 16 27 16 32 16 42 16 55 17 42 17 46 17 52 17 55
#  18 33 18 38 18 48 18 56 19 33 19 41 19 51 19 62 20 33 20 40 20 43 21 39
#  21 49 21 56 21 61 22 34 22 43 22 54 22 57 22 61 23 44 23 50 23 58 23 60
#  24 35 24 39 24 52 24 62 25 35 25 44 25 53 25 62 26 35 26 45 26 54 26 60]
# H: [36, 9, 10]
# H^T: [27, 0, inf]
# Q: [[2025, 81, 10]]
# Hx, Hz, Lx, Lz: (972, 2025), (972, 2025), (81, 2025), (81, 2025)
# BP max iterations: 202, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 423.0m 34.40s with 8092 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0016184 ± 0.0000180 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/exploration.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    cost_list = grp['values'][:]
    state_list = grp['states'][:]

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

params, Hx, Hz = get_code_parameters_and_matrices(best_state)
score_info = compute_weighted_low_weight_score(
    state=best_state,
    params=params,
    beta=0.3,
    max_weight_offset=4,
)
print(format_score_info(score_info))
# cost_result = evaluate_mc(
#     Hx,
#     Hz,
#     p,
#     MC_budget,
#     run_label=run_name,
#     failure_cap=None,
#     min_runs_before_stop=0,
#     workers=32,
#     batch_size=10000,
# )
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0277 in index 146
# [ 0 36  0 44  0 45  0 55  1 27  1 46  1 53  1 59  2 37  2 38  2 53  2 57
#   3 28  3 29  3 36  3 47  4 28  4 32  4 39  4 56  5 28  5 48  5 49  5 54
#   6 36  6 45  6 49  6 61  7 29  7 34  7 41  7 46  8 29  8 48  8 51  8 59
#   9 30  9 40  9 52  9 58 10 30 10 38 10 40 10 57 11 27 11 30 11 37 11 41
#  12 31 12 37 12 51 12 59 13 31 13 42 13 50 13 60 14 31 14 43 14 47 14 58
#  15 32 15 34 15 47 15 50 16 27 16 32 16 42 16 55 17 42 17 46 17 52 17 55
#  18 33 18 38 18 48 18 56 19 33 19 41 19 51 19 62 20 33 20 40 20 43 21 39
#  21 49 21 56 21 61 22 34 22 43 22 54 22 57 22 61 23 44 23 50 23 58 23 60
#  24 35 24 39 24 52 24 62 25 35 25 44 25 53 25 62 26 35 26 45 26 54 26 60]
# weight_patterns={10: 2, 11: 0, 12: 21, 13: 0, 14: 43}, score=4.2383

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/exploration.hdf5"
code_name = "[1600,64]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    cost_list = grp['values'][:]
    state_list = grp['states'][:]

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0012 in index 37
# [ 0 24  0 30  0 32  0 39  1 24  1 33  1 37  1 48  1 55  2 24  2 34  2 41
#   2 50  3 25  3 32  3 42  3 50  3 55  4 25  4 35  4 41  4 51  5 25  5 36
#   5 43  5 48  6 26  6 32  6 44  6 51  7 26  7 40  7 40  7 52  8 26  8 38
#   8 41  8 53  9 27  9 33  9 42  9 52 10 35 10 44 10 46 10 53 11 27 11 37
#  11 43 11 49 12 33 12 45 12 51 12 52 13 28 13 36 13 44 13 50 14 27 14 28
#  14 38 14 49 15 29 15 34 15 42 15 46 16 28 16 29 16 36 16 47 17 29 17 37
#  17 45 17 54 18 30 18 34 18 43 18 54 19 38 19 47 19 49 19 55 20 30 20 39
#  20 45 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 53 23 31 23 40 23 47]
# H: [32, 8, 10]
# H^T: [24, 0, inf]
# Q: [[1600, 64, 10]]
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 277.0m 12.10s with 10563 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0021126 ± 0.0000205 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_L15_old_parents_included_1e5_run1.hdf5"
code_name = "[1600,64]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # cost_list = grp['values'][:]
    # state_list = grp['states'][:]

    # min_cost = np.min(cost_list)
    # min_idx = np.argmin(cost_list)

    # print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}"

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 32  0 39  0 47  0 49  1 24  1 33  1 40  1 48  1 55  2 24  2 34  2 41
#    2 50  3 25  3 32  3 42  3 50  3 55  4 25  4 35  4 41  4 51  5 43  5 43
#    5 44  5 48  6 26  6 32  6 44  6 51  7 26  7 37  7 40  7 52  8 26  8 38
#    8 41  8 53  9 24  9 27  9 33  9 42 10 27 10 35 10 44 10 53 11 27 11 37
#   11 46 11 49 12 28 12 33 12 45 12 51 13 28 13 36 13 36 13 50 14 28 14 38
#   14 46 14 49 15 29 15 34 15 42 15 43 16 29 16 36 16 47 16 52 17 29 17 37
#   17 45 17 54 18 25 18 30 18 34 18 54 19 30 19 38 19 47 19 55 20 30 20 39
#   20 45 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 53 23 31 23 40 23 52]]
# H: [32, 8, 10]
# H^T: [24, 0, inf]
# Q: [[1600, 64, 10]]
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_L15_old_parents_included_1e5_run1.hdf5"
code_name = "[2025,81]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # cost_list = grp['values'][:]
    # state_list = grp['states'][:]

    # min_cost = np.min(cost_list)
    # min_idx = np.argmin(cost_list)

    # print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}"

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
