# %%
pip install h5py
# Out:
# Requirement already satisfied: h5py in ./.venv/lib/python3.12/site-packages (3.15.1)
# Requirement already satisfied: numpy>=1.21.2 in ./.venv/lib/python3.12/site-packages (from h5py) (2.3.4)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import h5py
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_d_first_L3.hdf5"
code_name = "[625,25]"  # Update this key if needed
p = 0.03
MC_budget = int(1e5)

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

    # Load Initial State
    # initial_state = load_tanner_graph(path_to_initial_codes + textfiles[C])
    initial_state = from_edgelist(best_state_edge_list)

    cost_result = evaluate_performance_of_state(
        state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# [[ 0 15  0 24  0 30  0 31  1 15  1 20  1 25  1 31  2 17  2 22  2 26  2 32
#    2 34  3 16  3 20  3 26  3 31  4 16  4 22  4 25  4 30  5 16  5 23  5 27
#    5 32  6 17  6 21  6 27  6 33  7 17  7 20  7 22  7 29  8 15  8 23  8 28
#    8 29  9 18  9 21  9 28  9 32 10 18 10 23 10 26 10 33 11 18 11 24 11 29
#   11 34 12 19 12 21 12 27 12 34 13 19 13 24 13 28 13 33 14 19 14 25 14 30]]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# [[625, 25, 8]]
# {'n_classical': 20, 'k_classical': 5, 'd_classical': 8, 'n_T_classical': 15, 'k_T_classical': 0, 'd_T_classical': inf, 'rank_H': 15, 'n_quantum': 625, 'k_quantum': 25, 'd_quantum': 8}
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Decoder Best neighbor search finished in 1.0m 13.87s with 550 failures out of 100000 runs.
# Logical error rate for Best neighbor search: 0.0055 ± 0.0002339 (stderr)

# %%
import h5py
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_d_first_L3.hdf5"
code_name = "[625,25]"  # Update this key if needed
p = 0.03
MC_budget = int(1e5)

idx = 542

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    # Load datasets
    # best_state_edge_list = grp["best_state"][:]
    # best_state = from_edgelist(best_state_edge_list)

    # print(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)

    cost_saved = grp['logical_error_rates'][:][idx]
    best_state_edge_list = grp['states'][:][idx]
    best_state = from_edgelist(best_state_edge_list)

    print(f"cost saved: {cost_saved}")

    print(best_state_edge_list)

    cost_result = evaluate_performance_of_state(
        state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# cost saved: 0.0042
# [ 0 15  0 24  0 30  0 31  1 15  1 20  1 25  1 31  2 17  2 22  2 26  2 32
#   2 34  3 16  3 20  3 27  3 31  4 16  4 22  4 25  4 30  5 16  5 23  5 26
#   5 32  6 17  6 21  6 27  6 33  7 17  7 20  7 22  7 30  8 15  8 23  8 28
#   8 29  9 18  9 21  9 28  9 32 10 18 10 23 10 26 10 33 11 18 11 24 11 29
#  11 34 12 19 12 21 12 27 12 34 13 19 13 24 13 28 13 33 14 19 14 25 14 29]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# [[625, 25, 8]]
# {'n_classical': 20, 'k_classical': 5, 'd_classical': 8, 'n_T_classical': 15, 'k_T_classical': 0, 'd_T_classical': inf, 'rank_H': 15, 'n_quantum': 625, 'k_quantum': 25, 'd_quantum': 8}
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Decoder Best neighbor search finished in 1.0m 9.85s with 530 failures out of 100000 runs.
# Logical error rate for Best neighbor search: 0.0053 ± 0.0002296 (stderr)

# %%
import h5py
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_d_first_L3.hdf5"
code_name = "[1600,64]"  # Update this key if needed
p = 0.03
MC_budget = int(1e5)

idx = 542

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    # print(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)

    # cost_saved = grp['logical_error_rates'][:][idx]
    # best_state_edge_list = grp['states'][:][idx]
    # best_state = from_edgelist(best_state_edge_list)

    print(f"cost saved: {min_cost}")

    print(best_state_edge_list)

    cost_result = evaluate_performance_of_state(
        state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# cost saved: 0.0008
# [[ 0 24  0 32  0 39  0 49  1 24  1 33  1 40  1 48  1 55  2 24  2 34  2 41
#    2 50  3 32  3 42  3 49  3 50  3 53  4 25  4 35  4 41  4 51  5 25  5 36
#    5 43  5 48  6 26  6 32  6 44  6 51  7 26  7 36  7 36  7 37  8 26  8 38
#    8 41  8 53  9 27  9 33  9 42  9 52 10 27 10 35 10 37 10 44 11 27 11 43
#   11 53 11 55 12 28 12 33 12 45 12 51 13 28 13 40 13 44 13 50 14 28 14 38
#   14 46 14 49 15 29 15 34 15 42 15 46 16 29 16 47 16 52 16 52 17 25 17 29
#   17 37 17 45 18 30 18 34 18 43 18 54 19 30 19 38 19 47 19 55 20 30 20 39
#   20 45 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 54 23 31 23 40 23 47]]
# H: [32, 8, 11]
# H^T: [24, 0, inf]
# [[1600, 64, 11]]
# {'n_classical': 32, 'k_classical': 8, 'd_classical': 11, 'n_T_classical': 24, 'k_T_classical': 0, 'd_T_classical': inf, 'rank_H': 24, 'n_quantum': 1600, 'k_quantum': 64, 'd_quantum': 11}
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 5.0m 54.37s with 138 failures out of 100000 runs.
# Logical error rate for Best neighbor search: 0.00138 ± 0.0001174 (stderr)

# %%
import h5py
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_d_first_L3.hdf5"
code_name = "[1600,64]"  # Update this key if needed
p = 0.03
MC_budget = int(1e6)

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)

    print(f"cost saved: {min_cost}")

    print(best_state_edge_list)

    cost_result = evaluate_performance_of_state(
        state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# cost saved: 0.0008
# [[ 0 24  0 32  0 39  0 49  1 24  1 33  1 40  1 48  1 55  2 24  2 34  2 41
#    2 50  3 32  3 42  3 49  3 50  3 53  4 25  4 35  4 41  4 51  5 25  5 36
#    5 43  5 48  6 26  6 32  6 44  6 51  7 26  7 36  7 36  7 37  8 26  8 38
#    8 41  8 53  9 27  9 33  9 42  9 52 10 27 10 35 10 37 10 44 11 27 11 43
#   11 53 11 55 12 28 12 33 12 45 12 51 13 28 13 40 13 44 13 50 14 28 14 38
#   14 46 14 49 15 29 15 34 15 42 15 46 16 29 16 47 16 52 16 52 17 25 17 29
#   17 37 17 45 18 30 18 34 18 43 18 54 19 30 19 38 19 47 19 55 20 30 20 39
#   20 45 21 31 21 35 21 46 21 54 22 31 22 39 22 48 22 54 23 31 23 40 23 47]]
# H: [32, 8, 11]
# H^T: [24, 0, inf]
# [[1600, 64, 11]]
# {'n_classical': 32, 'k_classical': 8, 'd_classical': 11, 'n_T_classical': 24, 'k_T_classical': 0, 'd_T_classical': inf, 'rank_H': 24, 'n_quantum': 1600, 'k_quantum': 64, 'd_quantum': 11}
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 119.0m 40.20s with 1451 failures out of 1000000 runs.
# Logical error rate for Best neighbor search: 0.001451 ± 0.0000381 (stderr)

# %%
import h5py
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/beam_search_d_first_L3.hdf5"
code_name = "[1600,64]"  # Update this key if needed
p = 0.03
MC_budget = int(1e5)

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    beam_survivors = grp['beam_survivors'][:]
    print(f"beam_survivors shape: {beam_survivors.shape}")
    print(f"beam_survivors[{idx}]: {beam_survivors[-1, 1]}")

    idx = beam_survivors[-1, 1]
    # Load datasets
    # best_state_edge_list = grp["best_state"][:]
    # best_state = from_edgelist(best_state_edge_list)

    # print(best_state_edge_list)

    min_cost = grp.attrs.get('min_cost', None)

    cost_saved = grp['logical_error_rates'][:][idx]
    best_state_edge_list = grp['states'][:][idx]
    best_state = from_edgelist(best_state_edge_list)

    print(f"cost saved: {cost_saved}")

    print(best_state_edge_list)

    cost_result = evaluate_performance_of_state(
        state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# beam_survivors shape: (6, 2)
# beam_survivors[403]: 403
# cost saved: 0.0009
# [ 0 24  0 32  0 39  0 49  1 24  1 33  1 37  1 40  1 55  2 24  2 34  2 41
#   2 50  3 32  3 42  3 49  3 50  3 53  4 25  4 35  4 41  4 51  5 25  5 36
#   5 43  5 48  6 26  6 32  6 44  6 51  7 26  7 36  7 36  7 37  8 26  8 38
#   8 41  8 53  9 27  9 33  9 42  9 52 10 27 10 35 10 44 10 48 11 27 11 43
#  11 53 11 55 12 28 12 33 12 45 12 51 13 28 13 40 13 44 13 50 14 28 14 38
#  14 46 14 49 15 29 15 34 15 42 15 46 16 29 16 47 16 52 16 52 17 29 17 37
#  17 45 17 54 18 30 18 34 18 43 18 54 19 30 19 38 19 47 19 55 20 30 20 39
#  20 45 21 31 21 35 21 46 21 54 22 25 22 31 22 39 22 48 23 31 23 40 23 47]
# H: [32, 8, 11]
# H^T: [24, 0, inf]
# [[1600, 64, 11]]
# {'n_classical': 32, 'k_classical': 8, 'd_classical': 11, 'n_T_classical': 24, 'k_T_classical': 0, 'd_T_classical': inf, 'rank_H': 24, 'n_quantum': 1600, 'k_quantum': 64, 'd_quantum': 11}
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (768, 1600), (768, 1600), (64, 1600), (64, 1600)
# BP max iterations: 160, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 6.0m 26.34s with 152 failures out of 100000 runs.
# Logical error rate for Best neighbor search: 0.00152 ± 0.0001232 (stderr)
