# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
import h5py

filepath = "optimization/results/beam_search_L15_old_parents_included_1e5_run1.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6)
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(f"Best state edge list: {best_state_edge_list}")


cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# Best state edge list: [[ 0 21  0 21  0 28  0 32  0 42  1 29  1 35  1 36  1 41  2 21  2 30  2 37
#    2 43  3 22  3 28  3 38  3 43  3 43  4 22  4 31  4 36  4 42  5 22  5 32
#    5 32  5 37  6 23  6 28  6 39  6 44  7 23  7 33  7 36  7 47  8 23  8 34
#    8 37  8 45  9 24  9 29  9 38  9 45 10 24 10 31 10 35 10 46 11 24 11 33
#   11 40 11 44 12 25 12 29 12 39 12 46 13 25 13 35 13 45 13 48 14 25 14 34
#   14 40 14 47 15 26 15 30 15 38 15 46 16 26 16 31 16 39 16 47 17 26 17 34
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 41 19 44 20 27 20 33 20 42]]
# H: [28, 7, 9]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 9]]
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 28.0m 35.05s with 2249 failures out of 1000000 runs.
# Logical error rate for Best neighbor search: 0.002249 ± 0.0000474 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
import h5py

filepath = "optimization/results/best_neighbor_search_early_stop.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6)
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(f"Best state edge list: {best_state_edge_list}")


cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# Best state edge list: [[ 0 21  0 28  0 30  0 42  0 48  1 21  1 36  1 38  1 41  2 21  2 35  2 37
#    2 43  3 22  3 28  3 29  3 43  3 47  4 22  4 31  4 36  4 42  5 22  5 32
#    5 37  5 44  6 28  6 39  6 40  6 47  7 23  7 33  7 36  7 43  8 23  8 25
#    8 45  8 47  9 24  9 29  9 38  9 45 10 24 10 31 10 35 10 46 11 23 11 24
#   11 33 11 44 12 29 12 37 12 39 12 46 13 25 13 32 13 35 13 45 14 25 14 34
#   14 40 14 44 15 26 15 30 15 38 15 46 16 26 16 31 16 34 16 39 17 26 17 34
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 32 19 41 20 27 20 33 20 42]]
# H: [28, 7, 10]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 10]]
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 36.0m 51.47s with 2322 failures out of 1000000 runs.
# Logical error rate for Best neighbor search: 0.002322 ± 0.0000481 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
import h5py

filepath = "optimization/results/beam_search_L15_old_parents_included_1e5_run1.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 20  0 25  0 28  0 30  1 15  1 21  1 21  1 31  2 15  2 22  2 26  2 32
#    2 34  3 16  3 20  3 27  3 31  4 16  4 22  4 25  4 30  5 16  5 23  5 27
#    5 32  6 17  6 20  6 27  6 33  7 17  7 22  7 29  7 33  8 17  8 30  8 31
#    8 34  9 18  9 21  9 28  9 32 10 18 10 23 10 26 10 33 11 18 11 24 11 29
#   11 34 12 15 12 19 12 23 12 26 13 19 13 24 13 24 13 28 14 19 14 25 14 29]]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Decoder Best neighbor search finished in 47.0m 31.32s with 18062 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0036124 ± 0.0000268 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/simulated_annealing.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 28  0 28  0 29  0 32  1 15  1 20  1 23  1 30  2 16  2 19  2 19  2 24
#    2 32  3 16  3 25  3 26  3 31  4 17  4 23  4 25  4 26  5 18  5 24  5 33
#    5 33  6 27  6 31  6 34  6 34  7 22  7 23  7 25  7 27  8 17  8 21  8 32
#    8 33  9 18  9 21  9 21  9 34 10 18 10 20 10 20 10 27 11 15 11 24 11 29
#   11 30 12 16 12 22 12 26 12 28 13 15 13 19 13 22 13 31 14 17 14 29 14 30]]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 42.0m 7.14s with 20584 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0041168 ± 0.0000286 (stderr)

# %% [markdown]
# # Random walk (BP+OSD)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist

filepath = "optimization/results/random_walk.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 15  0 20  0 24  0 30  1 15  1 21  1 25  1 31  2 15  2 22  2 22  2 26
#    2 32  3 16  3 20  3 26  3 31  4 16  4 22  4 25  4 30  5 16  5 23  5 27
#    5 32  6 17  6 20  6 27  6 33  7 17  7 28  7 29  7 34  8 17  8 23  8 30
#    8 31  9 18  9 21  9 28  9 32 10 18 10 23 10 26 10 33 11 18 11 24 11 29
#   11 34 12 19 12 21 12 27 12 34 13 19 13 24 13 28 13 33 14 19 14 25 14 29]]
# H: [20, 5, 7]
# H^T: [15, 0, inf]
# Q: [[625, 25, 7]]
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 50.0m 23.19s with 38503 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0077006 ± 0.0000391 (stderr)

# %%
from optimization.experiments_settings import from_edgelist
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
import numpy as np

filepath = "optimization/results/sim_ann_deltalog.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]
    beta4 = grp['beta=4']

    cost_list = beta4['cost']
    state_list = beta4['theta']

    min_cost = np.min(cost_list)
    min_idx = np.argmin(cost_list)

    print(f"logical error rate under erasure channel: {min_cost} in index {min_idx}")

    # Load datasets
    best_state_edge_list = state_list[min_idx]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# logical error rate under erasure channel: 0.0065 in index 759
# [ 0 19  0 23  0 30  0 32  1 18  1 27  1 28  1 30  2 24  2 27  2 28  2 34
#   2 34  3 16  3 17  3 18  3 34  4 15  4 15  4 21  4 28  5 23  5 24  5 25
#   5 32  6 16  6 22  6 26  6 32  7 15  7 20  7 23  7 25  8 17  8 19  8 22
#   8 30  9 20  9 27  9 31  9 33 10 17 10 18 10 19 10 33 11 21 11 24 11 29
#  11 31 12 25 12 29 12 29 12 31 13 21 13 26 13 26 13 33 14 16 14 20 14 22]
# H: [20, 5, 8]
# H^T: [15, 0, inf]
# Q: [[625, 25, 8]]
# Hx, Hz, Lx, Lz: (300, 625), (300, 625), (25, 625), (25, 625)
# BP max iterations: 62, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 68.0m 5.37s with 17571 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0035142 ± 0.0000265 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
import h5py

filepath = "optimization/results/best_neighbor_search_early_stop.hdf5"
code_name = "[1225,65]"  # Update this key if needed
MC_budget = int(1e6 * 5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    # Load datasets
    best_state_edge_list = grp["best_state"][:]
    best_state = from_edgelist(best_state_edge_list)

    print(best_state_edge_list)

cost_result = evaluate_performance_of_state(
    state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 5000000
# [[ 0 21  0 28  0 30  0 42  0 48  1 21  1 36  1 38  1 41  2 21  2 35  2 37
#    2 43  3 22  3 28  3 29  3 43  3 47  4 22  4 31  4 36  4 42  5 22  5 32
#    5 37  5 44  6 28  6 39  6 40  6 47  7 23  7 33  7 36  7 43  8 23  8 25
#    8 45  8 47  9 24  9 29  9 38  9 45 10 24 10 31 10 35 10 46 11 23 11 24
#   11 33 11 44 12 29 12 37 12 39 12 46 13 25 13 32 13 35 13 45 14 25 14 34
#   14 40 14 44 15 26 15 30 15 38 15 46 16 26 16 31 16 34 16 39 17 26 17 34
#   17 41 17 48 18 27 18 30 18 40 18 48 19 27 19 32 19 41 20 27 20 33 20 42]]
# H: [28, 7, 10]
# H^T: [21, 0, inf]
# Q: [[1225, 49, 10]]
# /Users/manyyeon/data/git/optimizing-qLDPC-code/.venv/lib/python3.12/site-packages/ldpc/code_util/code_util.py:164: UserWarning: This function has exponential complexity. Not recommended for large pcms. Use the                            'ldpc.code_util.estimate_code_distance' function instead.
#   warnings.warn(
# Hx, Hz, Lx, Lz: (588, 1225), (588, 1225), (49, 1225), (49, 1225)
# BP max iterations: 122, OSD order: 2, MS scaling factor: 0.625
# Decoder Best neighbor search finished in 232.0m 22.60s with 11769 failures out of 5000000 runs.
# Logical error rate for Best neighbor search: 0.0023538 ± 0.0000217 (stderr)

# %%
from optimization.analyze_codes.decoder_performance_from_state import evaluate_performance_of_state
from optimization.experiments_settings import from_edgelist
import h5py
import numpy as np

filepath = "optimization/results/best_neighbor_search_early_stop.hdf5"
code_name = "[625,25]"  # Update this key if needed
MC_budget = int(1e5)

print(f"MC_budget set to: {MC_budget}")
p = 0.03
k = 20

with h5py.File(filepath, "r") as f:
    grp = f[code_name]

    lers = grp['logical_error_rates'][:]
    # set 0 to inf
    lers = np.where(lers > 0, lers, np.inf)

    sorted_lers = sorted(lers)

    print(sorted_lers)
    top_k_min_lers = sorted_lers[:k]

    print(top_k_min_lers)

# cost_result = evaluate_performance_of_state(
#     state=best_state, p_vals=[p], MC_budget=MC_budget, canskip=False)
# Out:
# MC_budget set to: 100000
# [np.float64(0.00332), np.float64(0.00332), np.float64(0.0034), np.float64(0.0034), np.float64(0.00347), np.float64(0.00353), np.float64(0.00353), np.float64(0.00362), np.float64(0.00363), np.float64(0.00364), np.float64(0.00365), np.float64(0.00365), np.float64(0.00366), np.float64(0.00367), np.float64(0.00367), np.float64(0.00371), np.float64(0.00371), np.float64(0.00371), np.float64(0.00371), np.float64(0.00376), np.float64(0.00383), np.float64(0.00389), np.float64(0.00392), np.float64(0.00392), np.float64(0.00392), np.float64(0.004), np.float64(0.00411), np.float64(0.0042), np.float64(0.00449), np.float64(0.00455), np.float64(0.00457), np.float64(0.00457), np.float64(0.00458), np.float64(0.00463), np.float64(0.00469), np.float64(0.00473), np.float64(0.00485), np.float64(0.00489), np.float64(0.00492), np.float64(0.00495), np.float64(0.00496), np.float64(0.00501), np.float64(0.00506), np.float64(0.00513), np.float64(0.00513), np.float64(0.00514), np.float64(0.00515), np.float64(0.00516), np.float64(0.00517), np.float64(0.00518), np.float64(0.00519), np.float64(0.0052), np.float64(0.00529), np.float64(0.00529), np.float64(0.00538), np.float64(0.00538), np.float64(0.00542), np.float64(0.00545), np.float64(0.00551), np.float64(0.0056), np.float64(0.00563), np.float64(0.00569), np.float64(0.00573), np.float64(0.00574), np.float64(0.00594), np.float64(0.00612), np.float64(0.00613), np.float64(0.00616), np.float64(0.00619), np.float64(0.00622), np.float64(0.00625), np.float64(0.00629), np.float64(0.00629), np.float64(0.00629), np.float64(0.00642), np.float64(0.00644), np.float64(0.00649), np.float64(0.00652), np.float64(0.00685), np.float64(0.00687), np.float64(0.0069), np.float64(0.00692), np.float64(0.00704), np.float64(0.00705), np.float64(0.00708), np.float64(0.00713), np.float64(0.00731), np.float64(0.00759), np.float64(0.00779), np.float64(0.00794), np.float64(0.00797), np.float64(0.008), np.float64(0.00801), np.float64(0.00807), np.float64(0.00814), np.float64(0.01254), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.float64(inf), np.f ...
# [np.float64(0.00332), np.float64(0.00332), np.float64(0.0034), np.float64(0.0034), np.float64(0.00347), np.float64(0.00353), np.float64(0.00353), np.float64(0.00362), np.float64(0.00363), np.float64(0.00364), np.float64(0.00365), np.float64(0.00365), np.float64(0.00366), np.float64(0.00367), np.float64(0.00367), np.float64(0.00371), np.float64(0.00371), np.float64(0.00371), np.float64(0.00371), np.float64(0.00376)]
